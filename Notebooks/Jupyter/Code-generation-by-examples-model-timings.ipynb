# %% [markdown]
# # Code Generation by DSL Examples

# %% [markdown]
# ---
#
# ## Setup

# %%
from DSLExamples import *
from DataTypeSystem import * 
import pandas as pd

t = dsl_examples()
deduce_type(t)
# Out:
# Assoc(Atom(<class 'str'>), Assoc(Atom(<class 'str'>), Assoc(Atom(<class 'str'>), Atom(<class 'str'>), 20), 7), 4)

# %%
# %load_ext JupyterChatbook

# %% [markdown]
# ----
#
# ## Correctness and speed timings

# %% [markdown]
# Make an LLM example function for translation of LSA workflow building commands:

# %%
from LLMFunctionObjects import *;
from LLMPrompts import *

# Ollama model timings are on MacBook Pro M1.

# Very slow, ≈4m. Correct.
#conf = llm_configuration('Ollama', model = "gemma4:26b")

# Very slow, ≈3.2m. Correct.
# conf = llm_configuration('Ollama', model = "gemma4:26b", max_tokens = 500)

# Very slow, ≈4m. Wrong with the do-not-overthink-it prompt
# conf = llm_configuration('Ollama', model = "gemma4:26b", max_tokens = 500)

# Very slow, ≈4m. Wrong - generates lots of redundant code and explanations.
#conf = llm_configuration('Ollama', model = "gemma3:12b") 

# Fast, ≈25s. Wrong -- generates a bunch of explanations.
# conf = llm_configuration('Ollama', model = "qwen3-coder:30b")

# Slow, ≈1.5m. Wrong -- generates a bunch of explanations
#conf = llm_configuration('Ollama', model = "gpt-oss:20b")

# Very, very slow, ≈ 10.5m. Correct code followed by a Markdown table
#conf = llm_configuration('Ollama', model = "qwen3.5:9b")

# Very, very slow, ≈8m. Correct.
# Slow ≈5m with the do-not-overthink prompt. Correct.
#conf = llm_configuration('Ollama', model = "qwen3.6:35b")

# Fast, ≈25s, Wrong -- generates a bunch of explanations.
# conf = llm_configuration('Ollama', model = "llama3.2:latest")

# Fast, ≈15s, Wrong.
# conf = llm_configuration('Ollama', model = "gemma3:1b")

# Slowish, ≈1m. Wrong -- generates a bunch of code.
# conf = llm_configuration('Ollama', model = "gemma3:4b")

# Slow, ≈4.5m. Wrong -- generates a bunch of explanations and JSON structures.
# conf = llm_configuration('Ollama', model = "deepseek-r1:latest")

# Fast, ≈40s. Wrong -- generates a bunch of explanations.
# Very, very slow, ≈40m, with the do-not-overthink prompt, was interrupted.
#conf = llm_configuration('Ollama', model = "lfm2")

# Fast, ≈12s. Wrong generates a bunch of explanations.
# conf = llm_configuration('Ollama', model = "granite4.1:3b")

# Slowish, ≈1m. Generates a bunch of explanations. 
# conf = llm_configuration('Ollama', model = "granite4.1:8b")

# Very, very slow, ≈24+m. Had to be interrupted.
# conf = llm_configuration('Ollama', model = "medgemma1.5:4b")

# Fast, ≈4s. Wrong.
# conf = llm_configuration('ChatGPT', model = "gpt-4.1-mini")

# Fast, ≈5s. Wrong.
# conf = llm_configuration('ChatGPT', model = "gpt-4.1")

# Fast, ≈13s. Correct.
# conf = llm_configuration('ChatGPT', model = "gpt-5.3-chat-latest")

# Fast, ≈4s. Wrong.
# conf = llm_configuration('ChatGPT', model = "gpt-5.4-mini")

# Slowish, ≈45s, Correct
# conf = llm_configuration('ChatGPT', model = "gpt-5.5")

# Slowish, ≈40s. Correct.
# conf = llm_configuration('Gemini', model = "gemini-3.5-flash")

#llm_pipeline_segment = llm_example_function(dsl_examples('WL', 'LSAMon'), prompts = 'Do the generation by example as quickly as possible. Do not overthink it.' + llm_prompt('NothingElse')('Wolfram Language'), llm_evaluator = conf)
llm_pipeline_segment = llm_example_function(dsl_examples('WL', 'LSAMon'), llm_evaluator=conf)

# %% [markdown]
# ----
#
# ## Transform the comments log into a table

# %%
# %%chat -i=html

Make a table of timing and success statistics with columns:

    Provider, Model, Time, VerbalTimingCharacterization, Success(Correct/Wrong), Comments

using the following logs:

```
# Very slow, ≈4m. Correct.
#conf = llm_configuration('Ollama', model = "gemma4:26b")

# Very slow, ≈3.2m. Correct.
# conf = llm_configuration('Ollama', model = "gemma4:26b", max_tokens = 500)

# Very slow, ≈4m. Wrong with the do-not-overthink-it prompt
# conf = llm_configuration('Ollama', model = "gemma4:26b", max_tokens = 500)

# Very slow, ≈4m. Wrong - generates lots of redundant code and explanations.
#conf = llm_configuration('Ollama', model = "gemma3:12b") 

# Fast, ≈25s. Wrong -- generates a bunch of explanations.
# conf = llm_configuration('Ollama', model = "qwen3-coder:30b")

# Slow, ≈1.5m. Wrong -- generates a bunch of explanations
#conf = llm_configuration('Ollama', model = "gpt-oss:20b")

# Very, very slow, ≈ 10.5m. Correct code followed by a Markdown table
#conf = llm_configuration('Ollama', model = "qwen3.5:9b")

# Very, very slow, ≈8m. Correct.
# Slow ≈5m with the do-not-overthink prompt. Correct.
#conf = llm_configuration('Ollama', model = "qwen3.6:35b")

# Fast, ≈25s, Wrong -- generates a bunch of explanations.
# conf = llm_configuration('Ollama', model = "llama3.2:latest")

# Fast, ≈15s, Wrong.
# conf = llm_configuration('Ollama', model = "gemma3:1b")

# Slowish, ≈1m. Wrong -- generates a bunch of code.
# conf = llm_configuration('Ollama', model = "gemma3:4b")

# Slow, ≈4.5m. Wrong -- generates a bunch of explanations and JSON structures.
# conf = llm_configuration('Ollama', model = "deepseek-r1:latest")

# Fast, ≈40s. Wrong -- generates a bunch of explanations.
# Very, very slow, ≈40m, with the do-not-overthink prompt, was interrupted.
#conf = llm_configuration('Ollama', model = "lfm2")

# Fast, ≈12s. Wrong generates a bunch of explanations.
# conf = llm_configuration('Ollama', model = "granite4.1:3b")

# Slowish, ≈1m. Generates a bunch of explanations. 
# conf = llm_configuration('Ollama', model = "granite4.1:8b")

# Very, very slow, ≈24+m. Had to be interrupted.
# conf = llm_configuration('Ollama', model = "medgemma1.5:4b")

# Fast, ≈4s. Wrong.
# conf = llm_configuration('ChatGPT', model = "gpt-4.1-mini")

# Fast, ≈5s. Wrong.
# conf = llm_configuration('ChatGPT', model = "gpt-4.1")

# Fast, ≈13s. Correct.
# conf = llm_configuration('ChatGPT', model = "gpt-5.3-chat-latest")

# Fast, ≈4s. Wrong.
# conf = llm_configuration('ChatGPT', model = "gpt-5.4-mini")

# Slowish, ≈45s, Correct
# conf = llm_configuration('ChatGPT', model = "gpt-5.5")

# Slowish, ≈40s. Correct.
# conf = llm_configuration('Gemini', model = "gemini-3.5-flash")
```
# Out:
# ```html
# <table border="1" cellpadding="5" cellspacing="0">
#   <thead>
#     <tr>
#       <th>Provider</th>
#       <th>Model</th>
#       <th>Time</th>
#       <th>VerbalTimingCharacterization</th>
#       <th>Success (Correct/Wrong)</th>
#       <th>Comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma4:26b</td>
#       <td>≈4m</td>
#       <td>Very slow</td>
#       <td>Correct</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma4:26b</td>
#       <td>≈3.2m</td>
#       <td>Very slow</td>
#       <td>Correct</td>
#       <td>max_tokens = 500</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma4:26b</td>
#       <td>≈4m</td>
#       <td>Very slow</td>
#       <td>Wrong</td>
#       <td>with the do-not-overthink-it prompt</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma3:12b</td>
#       <td>≈4m</td>
#       <td>Very slow</td>
#       <td>Wrong</td>
# ...

# %% [markdown]
# <table border="1" cellpadding="5" cellspacing="0">
#   <thead>
#     <tr>
#       <th>Provider</th>
#       <th>Model</th>
#       <th>Time</th>
#       <th>VerbalTimingCharacterization</th>
#       <th>Success (Correct/Wrong)</th>
#       <th>Comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma4:26b</td>
#       <td>≈4m</td>
#       <td>Very slow</td>
#       <td>Correct</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma4:26b</td>
#       <td>≈3.2m</td>
#       <td>Very slow</td>
#       <td>Correct</td>
#       <td>max_tokens = 500</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma4:26b</td>
#       <td>≈4m</td>
#       <td>Very slow</td>
#       <td>Wrong</td>
#       <td>with the do-not-overthink-it prompt</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma3:12b</td>
#       <td>≈4m</td>
#       <td>Very slow</td>
#       <td>Wrong</td>
#       <td>generates lots of redundant code and explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>qwen3-coder:30b</td>
#       <td>≈25s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gpt-oss:20b</td>
#       <td>≈1.5m</td>
#       <td>Slow</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>qwen3.5:9b</td>
#       <td>≈10.5m</td>
#       <td>Very, very slow</td>
#       <td>Correct</td>
#       <td>Correct code followed by a Markdown table</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>qwen3.6:35b</td>
#       <td>≈8m</td>
#       <td>Very, very slow</td>
#       <td>Correct</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>qwen3.6:35b</td>
#       <td>≈5m</td>
#       <td>Slow</td>
#       <td>Correct</td>
#       <td>with the do-not-overthink prompt</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>llama3.2:latest</td>
#       <td>≈25s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma3:1b</td>
#       <td>≈15s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>gemma3:4b</td>
#       <td>≈1m</td>
#       <td>Slowish</td>
#       <td>Wrong</td>
#       <td>generates a bunch of code</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>deepseek-r1:latest</td>
#       <td>≈4.5m</td>
#       <td>Slow</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations and JSON structures</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>lfm2</td>
#       <td>≈40s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>lfm2</td>
#       <td>≈40m</td>
#       <td>Very, very slow</td>
#       <td>Interrupted</td>
#       <td>with the do-not-overthink prompt</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>granite4.1:3b</td>
#       <td>≈12s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>granite4.1:8b</td>
#       <td>≈1m</td>
#       <td>Slowish</td>
#       <td>Wrong</td>
#       <td>generates a bunch of explanations</td>
#     </tr>
#     <tr>
#       <td>Ollama</td>
#       <td>medgemma1.5:4b</td>
#       <td>≈24+m</td>
#       <td>Very, very slow</td>
#       <td>Interrupted</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ChatGPT</td>
#       <td>gpt-4.1-mini</td>
#       <td>≈4s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ChatGPT</td>
#       <td>gpt-4.1</td>
#       <td>≈5s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ChatGPT</td>
#       <td>gpt-5.3-chat-latest</td>
#       <td>≈13s</td>
#       <td>Fast</td>
#       <td>Correct</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ChatGPT</td>
#       <td>gpt-5.4-mini</td>
#       <td>≈4s</td>
#       <td>Fast</td>
#       <td>Wrong</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>ChatGPT</td>
#       <td>gpt-5.5</td>
#       <td>≈45s</td>
#       <td>Slowish</td>
#       <td>Correct</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Gemini</td>
#       <td>gemini-3.5-flash</td>
#       <td>≈40s</td>
#       <td>Slowish</td>
#       <td>Correct</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
